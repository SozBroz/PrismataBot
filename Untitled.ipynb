# %%
a=[1,2,3]
b=[4,5,6]
totalAttackPower=32
attackPowerNeeded=15
attackPossibilitiesGrid=[]
#####Every Unique Combination in descending order

print(totalAttackPower)
for i in range(0,len(a)):
    attackPossibilitiesGrid.append([])
    for f in range(0,b[i]+1):
        attackPossibilitiesGrid[i].append(a[i]*f)
print(attackPossibilitiesGrid)

for i in range(0,len(attackPossibilitiesGrid)):
    for f in range(0,len(attackPossibilitiesGrid[i])):
        for g in range(0,len(attackPossibilitiesGrid[i+1:])):
            for h in range(0,len(attackPossibilitiesGrid[i+1:][g])):
                print("i:",i)
                print("f:",f)
                print("attackPossibilitiesGrid[i][f]:", attackPossibilitiesGrid[i][f])
                print("attackPossibilitiesGrid[i+1:][g][h]",attackPossibilitiesGrid[i+1:][g][h])
                print("=",attackPossibilitiesGrid[i][f]+attackPossibilitiesGrid[i+1:][g][h])
# Out:
# 32
# [[0, 1, 2, 3, 4], [0, 2, 4, 6, 8, 10], [0, 3, 6, 9, 12, 15, 18]]
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 0
# = 0
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 2
# = 2
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 4
# = 4
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 6
# = 6
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 8
# = 8
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 10
# = 10
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 0
# = 0
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 3
# = 3
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# attackPossibilitiesGrid[i+1:][g][h] 6
# = 6
# i: 0
# f: 0
# attackPossibilitiesGrid[i][f]: 0
# ...
